# %%
from utils.config import process_config
from utils import factory

# %%
config = process_config('configs/dense_from_config.json')

# %%
data_loader = factory.create("data_loader." + config.data_loader.name)(config)
# Out:
# importing data_loader.dense_data_loader
# getattr DenseDataLoader
# <class 'data_loader.dense_data_loader.DenseDataLoader'>

# %%
# for x, y in data_loader.train_data:
#     print("x =", x.numpy())
#     print("y =", y.numpy())
print("")

# %%
list(data_loader.train_data.as_numpy_iterator())[1]
# Out:
# (array([[10697.25, 10698.89, 10702.04, 10706.33, 10708.64, 10707.46,
#          10705.36, 10712.58, 10709.85, 10713.88, 10717.51, 10716.57,
#          10716.15, 10717.18, 10716.77, 10708.19, 10705.18, 10699.62,
#          10701.66, 10702.15, 10700.16, 10698.84, 10690.67, 10682.23,
#          10686.11, 10684.21, 10688.21, 10690.2 , 10692.  , 10691.66],
#         [10658.32, 10652.52, 10651.96, 10651.09, 10648.01, 10661.03,
#          10671.34, 10668.18, 10665.87, 10662.49, 10663.15, 10666.19,
#          10670.25, 10667.6 , 10660.33, 10661.13, 10659.59, 10662.48,
#          10661.61, 10655.27, 10651.16, 10655.56, 10655.15, 10655.98,
#          10660.44, 10661.64, 10659.8 , 10660.21, 10658.92, 10658.91],
#         [10671.2 , 10670.58, 10670.66, 10666.23, 10662.11, 10660.7 ,
#          10660.  , 10667.28, 10669.53, 10703.01, 10716.88, 10720.84,
#          10717.73, 10715.73, 10708.97, 10702.  , 10698.84, 10705.86,
#          10706.79, 10705.98, 10703.98, 10703.16, 10698.84, 10703.39,
# ...
