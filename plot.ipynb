# %%
# %run ./main.py -c configs/moving_average_config.json

# %%
from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler
from matplotlib.pyplot import plot as plt
from datetime import datetime
import pandas as pd

# %%
series_df = read_csv("data/BTC-USD-2000-DAYtoTs.csv")
time_series = pd.to_datetime(series_df['time']).date()
# series_df = pd.concat([series_df, time_series.to_frame().T])
ax = series_df.plot(x='time', y='close')
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")

# %%
series_df = read_csv("data/BTC-USD-2000-DAYtoTs.csv")
ax = series_df.plot(x='time', y='close')
ax.set_xlabel("Date")
ax.set_ylabel("Close Price (USD)")
# Out:
# Text(0, 0.5, 'Close Price (USD)')

# %%
df = read_csv("data/testerino.csv")
scaler = MinMaxScaler(feature_range=(0, 1))
sdf_np = scaler.fit_transform(df)  # note: scaler converts df into numpy array
sdf = pd.DataFrame(sdf_np, columns=df.columns, index=df.index)

plt.figure(figsize=(12,6))
plt.grid()
plt.plot(sdf)
plt.legend(sdf.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-541e9f00b562> in <module>
#       1 df = read_csv("data/testerino.csv")
#       2 scaler = MinMaxScaler(feature_range=(0, 1))
# ----> 3 sdf_np = scaler.fit_transform(df)  # note: scaler converts df into numpy array
#       4 sdf = pd.DataFrame(sdf_np, columns=df.columns, index=df.index)
#       5
#
# ~\anaconda3\envs\tgpu\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\envs\tgpu\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     334         # Reset internal state before fitting
# ...
